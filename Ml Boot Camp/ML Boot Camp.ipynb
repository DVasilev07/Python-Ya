# %%
import pandas as pd
import numpy as np
import sklearn 
from sklearn import feature_selection

# %%
#Считывание
data_subs_f = pd.read_csv('subs_features_train.csv',';',decimal=',',parse_dates=['SNAP_DATE'])
data_subs_f.head(10)
#data_subs_f = data_subs_f.sort_values(['SNAP_DATE','SK_ID'])
data_subs_f = data_subs_f.sort_values(['SK_ID','SNAP_DATE'])
#data_subs_f = data_subs_f.sort_values([('SK_ID','SNAP_DATE')])
data_subs_f.head(10)
#data_subs_f['COM_CAT#1']
# Out:
#        SNAP_DATE  COM_CAT#1  SK_ID  COM_CAT#2  COM_CAT#3  BASE_TYPE  ACT  \
# 6503  2002-01-01          7      2         77         17          1    1
# 12304 2002-01-02          7      2         77          9          1    1
# 24981 2002-01-03          7      2         77         10          1    1
# 21704 2002-01-04          7      2         77         11          1    1
# 29381 2002-01-05          7      2         77         12          1    1
# 21807 2001-01-09          4      3         51         17          1    1
# 14399 2001-01-10          4      3         51          9          1    1
# 26898 2001-01-11          4      3         51         10          1    1
# 24566 2001-01-12          4      3         51         11          1    1
# 24326 2002-01-01          4      3         51         12          1    1
#
#        ARPU_GROUP  COM_CAT#7  COM_CAT#8     ...      COM_CAT#25  COM_CAT#26  \
# 6503          6.0          2     1318.0     ...               1           0
# ...

# %%
data_subs_f.head(15)
# Out:
#        SNAP_DATE  COM_CAT#1  SK_ID  COM_CAT#2  COM_CAT#3  BASE_TYPE  ACT  \
# 6503  2002-01-01          7      2         77         17          1    1
# 12304 2002-01-02          7      2         77          9          1    1
# 24981 2002-01-03          7      2         77         10          1    1
# 21704 2002-01-04          7      2         77         11          1    1
# 29381 2002-01-05          7      2         77         12          1    1
# 21807 2001-01-09          4      3         51         17          1    1
# 14399 2001-01-10          4      3         51          9          1    1
# 26898 2001-01-11          4      3         51         10          1    1
# 24566 2001-01-12          4      3         51         11          1    1
# 24326 2002-01-01          4      3         51         12          1    1
# 29547 2002-01-02          4      3         51         13          1    1
# 14397 2002-01-03          4      3         51         14          2    1
# ...

# %%
print ("Kolvo priznakov s null = ",test.index[data_subs_f.isnull().any()].size )
# Проверка незаполненных значений
print (data_subs_f.isnull().any())
#test = data_subs_f.isnull().any()
# Out:
# ('Kolvo priznakov s null = ', 5)
# SNAP_DATE           False
# COM_CAT#1           False
# SK_ID               False
# COM_CAT#2           False
# COM_CAT#3           False
# BASE_TYPE           False
# ACT                 False
# ARPU_GROUP           True
# COM_CAT#7           False
# COM_CAT#8            True
# DEVICE_TYPE_ID       True
# INTERNET_TYPE_ID     True
# REVENUE             False
# ITC                 False
# VAS                 False
# RENT_CHANNEL        False
# ROAM                False
# COST                False
# COM_CAT#17          False
# COM_CAT#18          False
# COM_CAT#19          False
# COM_CAT#20          False
# COM_CAT#21          False
# COM_CAT#22          False
# COM_CAT#23          False
# COM_CAT#25          False
# COM_CAT#26          False
# COM_CAT#27          False
# COM_CAT#28          False
# COM_CAT#29          False
# COM_CAT#30          False
# COM_CAT#31          False
# COM_CAT#32          False
# COM_CAT#33          False
# ...

# %%
# Посмотреть на них
data_subs_f.loc[data_subs_f['ARPU_GROUP'].isnull()]
# Out:
#        SNAP_DATE  COM_CAT#1  SK_ID  COM_CAT#2  COM_CAT#3  BASE_TYPE  ACT  \
# 35605 2002-01-05          2    546         37          1          2    1
# 20410 2002-01-04          1    804         30          5          2    1
# 30089 2001-01-08          7   1049         49          5          2    1
# 3316  2001-01-12          1   1307         30          5          2    1
# 12754 2002-01-02          2   1860         18          1          2    1
# 18755 2001-01-09          6   2041         35         11          1    1
# 21132 2001-01-09          5   2149         33          5          2    1
# 12016 2002-01-01          5   2321         60          5          2    1
# 5515  2002-01-02          6   2372          2         15          2    1
# 4129  2001-01-12          3   2839         65         10          1    0
# 37005 2001-01-08          7   3092         77          4          2    1
# 6914  2002-01-01          5   3275         41          5          2    1
# ...

# %%
# Число незаполненных атрибутов в конкретном столбце
print len(data_subs_f.index[data_subs_f['ARPU_GROUP'].isnull()].tolist())
print len(data_subs_f.index[data_subs_f['COM_CAT#8'].isnull()].tolist())
print len(data_subs_f.index[data_subs_f['DEVICE_TYPE_ID'].isnull()].tolist())
print len(data_subs_f.index[data_subs_f['INTERNET_TYPE_ID'].isnull()].tolist())
print len(data_subs_f.index[data_subs_f['COM_CAT#34'].isnull()].tolist())
# Out:
# 18
# 86
# 86
# 86
# 1390

# %%
data_subs_f.dtypes
# Out:
# SNAP_DATE           datetime64[ns]
# COM_CAT#1                    int64
# SK_ID                        int64
# COM_CAT#2                    int64
# COM_CAT#3                    int64
# BASE_TYPE                    int64
# ACT                          int64
# ARPU_GROUP                 float64
# COM_CAT#7                    int64
# COM_CAT#8                  float64
# DEVICE_TYPE_ID             float64
# INTERNET_TYPE_ID           float64
# REVENUE                    float64
# ITC                        float64
# VAS                        float64
# RENT_CHANNEL               float64
# ROAM                       float64
# COST                       float64
# COM_CAT#17                 float64
# COM_CAT#18                 float64
# COM_CAT#19                 float64
# COM_CAT#20                 float64
# COM_CAT#21                 float64
# COM_CAT#22                 float64
# COM_CAT#23                 float64
# COM_CAT#25                   int64
# COM_CAT#26                   int64
# ...

# %%
# Дропнем 24 там везде 31 декабря - непонятная дата
data_subs_f = data_subs_f.drop('COM_CAT#24', 1)

# %%
# Разбиение на категориальные и числовые
numeric_cols = ['COM_CAT#8','REVENUE','ITC','VAS','RENT_CHANNEL','COST',
                'COM_CAT#17','COM_CAT#20','COM_CAT#21','COM_CAT#22','COM_CAT#23',
               'COM_CAT#27','COM_CAT#28','COM_CAT#29','COM_CAT#30','COM_CAT#31']
categorical_cols = list(set(data_subs_f.columns.values.tolist()) - set(numeric_cols))

# %%
categorical_cols
# Out:
# ['COM_CAT#2',
#  'INTERNET_TYPE_ID',
#  'SK_ID',
#  'COM_CAT#34',
#  'COM_CAT#3',
#  'ROAM',
#  'COM_CAT#26',
#  'BASE_TYPE',
#  'COM_CAT#32',
#  'COM_CAT#33',
#  'ARPU_GROUP',
#  'COM_CAT#1',
#  'COM_CAT#25',
#  'COM_CAT#7',
#  'SNAP_DATE',
#  'ACT',
#  'DEVICE_TYPE_ID',
#  'COM_CAT#18',
#  'COM_CAT#19']

# %%
X = data_subs_f[categorical_cols]

# %%
X_test = X[['SK_ID','COM_CAT#18','COM_CAT#19','COM_CAT#32','COM_CAT#33']]

# %%
print X_test.nunique()
print X_test.shape
# Out:
# SK_ID         3622
# COM_CAT#18     775
# COM_CAT#19     114
# COM_CAT#32    1637
# COM_CAT#33    2606
# dtype: int64
# (40638, 5)

# %%
selector = sklearn.feature_selection.VarianceThreshold()

# %%
selector.fit_transform(X_test)
# Out:
# array([[  2.00000000e+00,   0.00000000e+00,   1.42530000e-02,
#           4.91890000e-02,   2.75080000e-01],
#        [  2.00000000e+00,   0.00000000e+00,   1.42530000e-02,
#           4.91890000e-02,   2.75080000e-01],
#        [  2.00000000e+00,   0.00000000e+00,   1.42530000e-02,
#           4.91890000e-02,   2.75080000e-01],
#        ...,
#        [  4.70100000e+03,   0.00000000e+00,   1.42530000e-02,
#           4.91890000e-02,   2.75080000e-01],
#        [  4.70100000e+03,   0.00000000e+00,   1.42530000e-02,
#           4.91890000e-02,   2.75080000e-01],
#        [  4.70100000e+03,   0.00000000e+00,   1.42530000e-02,
#           4.91890000e-02,   2.75080000e-01]])

# %%
data_subs_f[['COM_CAT#18','COM_CAT#19','COM_CAT#32','COM_CAT#33']]
# Out:
#        COM_CAT#18  COM_CAT#19  COM_CAT#32  COM_CAT#33
# 6503          0.0    0.014253    0.049189    0.275080
# 12304         0.0    0.014253    0.049189    0.275080
# 24981         0.0    0.014253    0.049189    0.275080
# 21704         0.0    0.014253    0.049189    0.275080
# 29381         0.0    0.014253    0.049189    0.275080
# 21807         0.0    0.014253    0.049189    0.275080
# 14399         0.0    0.014253    0.049189    0.275080
# 26898         0.0    0.014253    0.049189    0.275080
# 24566         0.0    0.014253    0.049189    0.275080
# 24326         0.0    0.014253    0.049189    0.275080
# 29547         0.0    0.014253    0.049189    0.275080
# 14397         0.0    0.014253    0.049189    0.275080
# 37161         0.0    0.014253    0.049189    0.275080
# 14398         0.0    0.014253    0.049189    0.275080
# 40584         0.0    0.014253    0.049189    0.275080
# 27649         0.0    0.014253    0.049189    0.275080
# ...

# %%
data_subs_f.iloc[0:15,22:]
# Out:
#        COM_CAT#21  COM_CAT#22  COM_CAT#23  COM_CAT#25  COM_CAT#26  COM_CAT#27  \
# 6503     0.016110    0.701424    0.118129           1           0    0.001798
# 12304    0.016110    0.707528    0.134836           1           1    0.003913
# 24981    0.016110    0.706893    0.133897           1           1    0.002070
# 21704    0.016110    0.704850    0.126587           1           1    0.006520
# 29381    0.016110    0.705129    0.129093           1           1    0.001801
# 21807    0.016110    0.700528    0.115501           1           0    0.000000
# 14399    0.024902    0.700275    0.127683           1           1    0.000625
# 26898    0.020543    0.699858    0.121696           1           1    0.012354
# 24566    0.021316    0.699855    0.123837           1           1    0.020497
# 24326    0.020506    0.700891    0.122636           1           1    0.002012
# 29547    0.018197    0.699068    0.115193           1           1    0.001383
# ...

# %%
# Попытки создания словаря
data_subs_f
d = dict(data_subs_f['ARPU_GROUP'])

# %%
d
# Out:
# {0: 6.0,
#  1: 3.0,
#  2: 11.0,
#  3: 12.0,
#  4: 12.0,
#  5: 9.0,
#  6: 7.0,
#  7: 10.0,
#  8: 3.0,
#  9: 8.0,
#  10: 6.0,
#  11: 12.0,
#  12: 1.0,
#  13: 4.0,
#  14: 8.0,
#  15: 9.0,
#  16: 2.0,
#  17: 7.0,
#  18: 12.0,
#  19: 10.0,
#  20: 1.0,
#  21: 11.0,
#  22: 5.0,
#  23: 7.0,
#  24: 8.0,
#  25: 6.0,
#  26: 12.0,
#  27: 12.0,
#  28: 11.0,
#  29: 10.0,
#  30: 9.0,
#  31: 10.0,
#  32: 6.0,
#  33: 8.0,
#  34: 1.0,
#  35: 7.0,
#  36: 6.0,
#  37: 9.0,
#  38: 5.0,
#  39: 7.0,
#  40: 8.0,
#  41: 6.0,
#  42: 12.0,
#  43: 8.0,
#  44: 5.0,
#  45: 5.0,
#  46: 8.0,
#  47: 12.0,
#  48: 7.0,
#  49: 6.0,
#  50: 6.0,
#  51: 6.0,
#  52: 7.0,
#  53: 8.0,
#  54: 10.0,
#  55: 5.0,
#  56: 4.0,
#  57: 9.0,
#  58: 5.0,
#  59: 6.0,
#  60: 7.0,
#  61: 7.0,
#  62: 7.0,
#  63: 8.0,
#  64: 5.0,
#  65: 9.0,
#  66: 7.0,
#  67: 12.0,
#  68: 9.0,
#  69: 12.0,
#  70: 7.0,
#  71: 8.0,
#  72: 7.0,
#  73: 11.0,
#  74: 5.0,
#  75: 12.0,
#  76: 6.0,
#  77: 5.0,
#  78: 6.0,
#  79: 7.0,
#  80: 1.0,
#  81: 12.0,
# ...
