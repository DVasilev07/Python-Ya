# %%
import pandas as pd
import numpy as np
import sklearn 
from sklearn import feature_selection
import matplotlib.pyplot as plt
from sklearn.cluster.hierarchical import AgglomerativeClustering

# %%
# %%time
#Считываем
fname = r'/Users/dmitri/Documents/ML_Boot Camp/csi_analyze/bs_avg_kpi.csv'
cell_d_columns = ['T_DATE','CELL_LAC_ID', 'ERAB_PS_BLOCKING_RATE_LTE','ERAB_PS_DROP_RATE_LTE','RAB_PS_BLOCKING_RATE_3G',
              'RAB_PS_DROP_RATE_3G','TBF_DROP_RATE_2G']
cell_d = pd.read_csv(fname,';',decimal=',',parse_dates=['T_DATE'],usecols = cell_d_columns, nrows = 10000)

# Работа с форматом day.month
ar = np.array(cell_d['T_DATE'])
month_ar = []
day_ar = []
for i in range(len(ar)):
    month = ar[i][3:5]
    day = ar[i][0:2]
    month_ar.append(month)
    day_ar.append(day)
    
cell_d['month'] = month_ar
cell_d['day'] = day_ar
cell_d.sort_values(['CELL_LAC_ID','month','day'])

# Чистим пустое

cell_d_nan = cell_d[['ERAB_PS_BLOCKING_RATE_LTE','ERAB_PS_DROP_RATE_LTE','RAB_PS_BLOCKING_RATE_3G',
              'RAB_PS_DROP_RATE_3G','TBF_DROP_RATE_2G']]
cell_d_nan = cell_d_nan.fillna(0)
array = np.array(cell_d_nan)

# Кластеризация сот по интернетам
#model = AgglomerativeClustering(n_clusters=3)
#preds_bad_d_cells = model.fit_predict(array)
# Out:
# CPU times: user 48.9 ms, sys: 10.4 ms, total: 59.3 ms
# Wall time: 65.5 ms

# %%
# %%time
# Кластеризация сот по интернетам
model = AgglomerativeClustering(n_clusters=3)
preds_bad_d_cells = model.fit(array)
# Out:
# CPU times: user 2.55 s, sys: 285 ms, total: 2.83 s
# Wall time: 2.87 s

# %%
cell_d_nan_min = cell_d_nan[['ERAB_PS_DROP_RATE_LTE','RAB_PS_DROP_RATE_3G','TBF_DROP_RATE_2G']]
cell_d_nan_min = cell_d_nan['ERAB_PS_DROP_RATE_LTE']

# %%
cell_d_nan_min
# Out:
#         ERAB_PS_DROP_RATE_LTE  TBF_DROP_RATE_2G
# 0                    0.006851          0.000000
# 1                    0.027000          0.000000
# 2                    0.035126          0.000000
# 3                    0.029308          0.000000
# 4                    0.008983          0.000000
# 5                    0.016665          0.000000
# 6                    0.019227          0.000000
# 7                    0.000000          0.000000
# 8                    0.002790          0.000000
# 9                    0.011725          0.000000
# 10                   0.021658          0.000000
# 11                   0.010319          0.000000
# 12                   0.000000          0.000000
# 13                   0.000000          0.000063
# 14                   0.000000          0.000000
# 15                   0.000000          0.000000
# 16                   0.000000          0.000000
# 17                   0.000000          0.000000
# 18                   0.000000          0.000000
# 19                   0.000000          0.000000
# 20                   0.000000          0.000013
# 21                   0.000000          0.000018
# 22                   0.000000          0.000000
# 23                   0.000000          0.000025
# 24                   0.000000          0.000000
# 25                   0.000000          0.000000
# 26                   0.000000          0.000031
# 27                   0.000000          0.000000
# 28                   0.000000          0.000020
# 29                   0.000000          0.000051
# ...                       ...               ...
# 499970               0.000000          0.000000
# 499971               0.000000          0.000000
# 499972               0.000000          0.000000
# 499973               0.000000          0.000000
# 499974               0.000000          0.000000
# 499975               0.000000          0.000000
# 499976               0.000000          0.000000
# 499977               0.000000          0.000000
# 499978               0.000000          0.000000
# 499979               0.000000          0.000000
# 499980               0.000000          0.000000
# 499981               0.000000          0.000000
# 499982               0.000000          0.000000
# 499983               0.000000          0.000000
# 499984               0.000000          0.000000
# 499985               0.000000          0.000000
# 499986               0.000000          0.000000
# 499987               0.000000          0.000000
# 499988               0.000000          0.000000
# 499989               0.000000          0.000000
# 499990               0.000000          0.000000
# 499991               0.000000          0.000000
# 499992               0.040289          0.000000
# 499993               0.008343          0.000000
# 499994               0.034340          0.000000
# 499995               0.016824          0.000000
# 499996               0.036509          0.000000
# 499997               0.052159          0.000000
# 499998               0.037617          0.000000
# 499999               0.056537          0.000000
#
# [500000 rows x 2 columns]

# %%
array = np.array(cell_d_nan_min)

# Кластеризация сот по интернетам
model = AgglomerativeClustering(n_clusters=2)
preds_bad_d_cells = model.fit_predict(array)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-f135d4a4d06b> in <module>()
#       3 # Кластеризация сот по интернетам
#       4 model = AgglomerativeClustering(n_clusters=2)
# ----> 5 preds_bad_d_cells = model.fit_predict(array)
#
# /anaconda2/lib/python2.7/site-packages/sklearn/base.pyc in fit_predict(self, X, y)
#     408         # non-optimized default implementation; override when a better
#     409         # method is possible for a given clustering algorithm
# --> 410         self.fit(X)
#     411         return self.labels_
#     412
#
# /anaconda2/lib/python2.7/site-packages/sklearn/cluster/hierarchical.pyc in fit(self, X, y)
#     694         self
#     695         """
# --> 696         X = check_array(X, ensure_min_samples=2, estimator=self)
#     697         memory = check_memory(self.memory)
#     698
#
# /anaconda2/lib/python2.7/site-packages/sklearn/utils/validation.pyc in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     439                     "Reshape your data either using array.reshape(-1, 1) if "
#     440                     "your data has a single feature or array.reshape(1, -1) "
# --> 441                     "if it contains a single sample.".format(array))
#     442             array = np.atleast_2d(array)
#     443             # To ensure that array flags are maintained
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[0.006851 0.027    0.035126 ... 0.052159 0.037617 0.056537].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
preds_bad_d_cells[]

# %%
cell_d_nan = cell_d_nan.loc[cell_d_nan.ne(0).all(axis=1)]

# %%
cell_d_nan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23274487 entries, 0 to 23274486
# Data columns (total 5 columns):
# ERAB_PS_BLOCKING_RATE_LTE    float64
# ERAB_PS_DROP_RATE_LTE        float64
# RAB_PS_BLOCKING_RATE_3G      float64
# RAB_PS_DROP_RATE_3G          float64
# TBF_DROP_RATE_2G             float64
# dtypes: float64(5)
# memory usage: 887.9 MB

# %%
cell_d_nan.loc[cell_d_nan.ne(0).all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ERAB_PS_BLOCKING_RATE_LTE, ERAB_PS_DROP_RATE_LTE, RAB_PS_BLOCKING_RATE_3G, RAB_PS_DROP_RATE_3G, TBF_DROP_RATE_2G]
# Index: []

# %%
cell_d_nan.ne(0).all(axis = 1)
# Out:
# False

# %%
# Импортируем библиотеки
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt
import pandas as pd
 
# Создаем датафрейм
seeds_df = pd.read_csv(
'http://qps.ru/jNZUT')
 
# Исключаем информацию об образцах зерна, сохраняем для дальнейшего использования
varieties = list(seeds_df.pop('grain_variety'))
 
# Извлекаем измерения как массив NumPy
samples = seeds_df.values
 
# Реализация иерархической кластеризации при помощи функции linkage
mergings = linkage(samples, method='complete')
 
# Строим дендрограмму, указав параметры удобные для отображения
dendrogram(mergings,
           labels=varieties,
           leaf_rotation=90,
           leaf_font_size=6,
           )
 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-8-2f65dff85dea> in <module>()
#       7 # Создаем датафрейм
#       8 seeds_df = pd.read_csv(
# ----> 9 'http://qps.ru/jNZUT')
#      10
#      11 # Исключаем информацию об образцах зерна, сохраняем для дальнейшего использования
#
# /anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# /anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# /anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# /anaconda2/lib/python2.7/site-packages/pandas/io/parsers.pyc in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 5, saw 2
